# %% [markdown]
# <span style="color: #79dbba; font-family: Old English Text MT; font-size:40px;font-weight:bold;">Assignment 2</span>

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

print("Largest number is:", largest)
# Out:
# Enter first number:  32
# Enter second number:  47
# Enter third number:  31
# Largest number is: 47
